# %%
import pandas as pd

# %%
#Load the data car_scrape4 dataset, find the sum of

# %%
new_df = pd.read_csv('car_scrape4.csv')

# %%
new_df.head()
# Out:
#                    title  odometer location    isimported          engine  \
# 0         Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1              Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2           Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3  Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4    Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
#
#   transmission    fuel   paint    price  year
# 0    automatic  petrol  Silver  1995000  2009
# 1    automatic  petrol  Whine   3315000  2009
# 2    automatic  petrol  Silver  2355000  2008
# 3    automatic  petrol   Black  9915000  2013
# 4    automatic  petrol   Black  9790000  2013

# %%
filled_df=new_df[new_df.notnull()].head()
filled_df
# Out:
#                    title  odometer location    isimported          engine  \
# 0         Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1              Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2           Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3  Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4    Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
#
#   transmission    fuel   paint    price  year
# 0    automatic  petrol  Silver  1995000  2009
# 1    automatic  petrol  Whine   3315000  2009
# 2    automatic  petrol  Silver  2355000  2008
# 3    automatic  petrol   Black  9915000  2013
# 4    automatic  petrol   Black  9790000  2013

# %%
new_df.isnull()
# Out:
#       title  odometer  location  isimported  engine  transmission   fuel  \
# 0     False     False     False       False   False         False  False
# 1     False     False     False       False   False         False  False
# 2     False     False     False       False   False         False  False
# 3     False     False     False       False   False         False  False
# 4     False     False     False       False   False         False  False
# ...     ...       ...       ...         ...     ...           ...    ...
# 3171  False     False     False       False   False         False  False
# 3172  False     False     False       False   False         False  False
# 3173  False     False     False       False   False         False  False
# 3174  False     False     False       False   False         False  False
# 3175  False     False     False       False   False         False  False
#
#       paint  price   year
# 0     False  False  False
# 1     False  False  False
# ...

# %%
finding = new_df.dropna(how='all').dropna(how='all', axis=1)
finding
# Out:
#                       title  odometer location    isimported          engine  \
# 0            Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1                 Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2              Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3     Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4       Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
# ...                     ...       ...      ...           ...             ...
# 3171          Ford Explorer    108597    Abuja  Foreign Used  6-cylinder(V6)
# 3172              Ford Edge    145184    Lagos  Foreign Used  6-cylinder(I6)
# 3173           Toyota Camry     88687    Lagos  Foreign Used  4-cylinder(I4)
# 3174      Toyota Highlander     30951    Lagos  Foreign Used  6-cylinder(V6)
# 3175           Toyota Camry     12936    Lagos  Foreign Used  4-cylinder(I4)
#
# ...

# %%
summing =finding["price"]
summing
# Out:
# 0        1995000
# 1        3315000
# 2        2355000
# 3        9915000
# 4        9790000
#           ...
# 3171     8675000
# 3172     4437000
# 3173     3175000
# 3174    17535000
# 3175    17015000
# Name: price, Length: 3176, dtype: int64

# %%
total = summing.sum()
print("The sum of the prices of the cars is: $", total)
# Out:
# The sum of the prices of the cars is: $ 27214291658

# %%
minimum = finding[finding['price'] == finding['price'].min()]
minimum
# Out:
#                title  odometer location    isimported          engine  \
# 601  Volkswagen Golf    200000    Abuja  Locally used  4-cylinder(I4)
#
#     transmission    fuel    paint   price  year
# 601       manual  petrol  Silver   215000  1998

# %%
summing.min()
# Out:
# 215000

# %%
highest = finding[finding['price'] == finding['price'].max()]
highest
# Out:
#                       title  odometer location isimported            engine  \
# 223   Mercedes-Benz Maybach      6758    Lagos       New   12-cylinder(V12)
# 1676  Mercedes-Benz Maybach      6758    Lagos       New   12-cylinder(V12)
# 3129  Mercedes-Benz Maybach      6758    Lagos       New   12-cylinder(V12)
#
#      transmission    fuel  paint      price  year
# 223     automatic  petrol  Black  167015008  2019
# 1676    automatic  petrol  Black  167015008  2019
# 3129    automatic  petrol  Black  167015008  2019

# %%
print("The mean of the prices of the car is $", summing.mean())
# Out:
# The mean of the prices of the car is $ 8568731.630352644
